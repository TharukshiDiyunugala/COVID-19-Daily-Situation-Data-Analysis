# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plot

# %%
data = pd.read_csv(r"C:/Users/MSI/Downloads/archive (1)/daily situation.csv")

# %%
data
# Out:
#      Number inward as at yesterday-10 am  COVID 19 Positive - last 24H  \
# 0                                    104                            21
# 1                                    123                             5
# 2                                    124                             3
# 3                                    125                             8
# 4                                    129                             7
# ..                                   ...                           ...
# 407                                23857                          2269
# 408                                19036                          2289
# 409                                19944                          2386
# 410                                21208                          2275
# 411                                22155                          2456
#
#      Discharged from the hospital - last 24H  Number of deaths - last 24H  \
# ...

# %%
data.columns
# Out:
# Index(['Number inward as at yesterday-10 am', 'COVID 19 Positive - last 24H',
#        'Discharged from the hospital - last 24H',
#        'Number of deaths - last 24H', 'Number inward as at today-10 am',
#        'Date', 'Total Number Confirmed', 'Total Number Recovered',
#        'Total Number of Deaths'],
#       dtype='object')

# %%
data.tail()
# Out:
#      Number inward as at yesterday-10 am  COVID 19 Positive - last 24H  \
# 407                                23857                          2269
# 408                                19036                          2289
# 409                                19944                          2386
# 410                                21208                          2275
# 411                                22155                          2456
#
#      Discharged from the hospital - last 24H  Number of deaths - last 24H  \
# 407                                     1306                           24
# 408                                     1352                           29
# 409                                     1102                           20
# 410                                     1307                           21
# 411                                     1516                           19
#
#      Number inward as at today-10 am         Date  Total Number Confirmed  \
# ...

# %%
data.describe()
# Out:
#        Number inward as at yesterday-10 am  COVID 19 Positive - last 24H  \
# count                           412.000000                    412.000000
# mean                           3330.140777                    352.118932
# std                            4075.585252                    489.184443
# min                             103.000000                      0.000000
# 25%                             356.250000                     11.000000
# 50%                            2294.500000                    200.500000
# 75%                            5603.250000                    532.750000
# max                           23857.000000                   2672.000000
#
#        Discharged from the hospital - last 24H  Number of deaths - last 24H  \
# count                               412.000000                   412.000000
# mean                                279.958738                     2.378641
# std                                 342.386011                     4.145449
# ...

# %%
data.isnull().sum()
# Out:
# Number inward as at yesterday-10 am        0
# COVID 19 Positive - last 24H               0
# Discharged from the hospital - last 24H    0
# Number of deaths - last 24H                0
# Number inward as at today-10 am            0
# Date                                       0
# Total Number Confirmed                     0
# Total Number Recovered                     0
# Total Number of Deaths                     0
# dtype: int64

# %%
data.describe()
# Out:
#        Number inward as at yesterday-10 am  COVID 19 Positive - last 24H  \
# count                           412.000000                    412.000000
# mean                           3330.140777                    352.118932
# std                            4075.585252                    489.184443
# min                             103.000000                      0.000000
# 25%                             356.250000                     11.000000
# 50%                            2294.500000                    200.500000
# 75%                            5603.250000                    532.750000
# max                           23857.000000                   2672.000000
#
#        Discharged from the hospital - last 24H  Number of deaths - last 24H  \
# count                               412.000000                   412.000000
# mean                                279.958738                     2.378641
# std                                 342.386011                     4.145449
# ...

# %%
data.columns
# Out:
# Index(['Number inward as at yesterday-10 am', 'COVID 19 Positive - last 24H',
#        'Discharged from the hospital - last 24H',
#        'Number of deaths - last 24H', 'Number inward as at today-10 am',
#        'Date', 'Total Number Confirmed', 'Total Number Recovered',
#        'Total Number of Deaths'],
#       dtype='object')

# %% [markdown]
# # Relating the variables with sactterplots

# %%
 sns.relplot(x="Total Number Confirmed",y="Total Number Recovered",data = data)
# Out:
# C:\Users\MSI\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
 sns.relplot(x="Total Number Confirmed",y="Total Number of Deaths",data = data)
# Out:
# C:\Users\MSI\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
 sns.relplot(x="Total Number Confirmed",y="Number inward as at today-10 am",hue = 'Total Number Recovered', data = data)
# Out:
# C:\Users\MSI\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(data)
# Out:
# C:\Users\MSI\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
data.columns
# Out:
# Index(['Number inward as at yesterday-10 am', 'COVID 19 Positive - last 24H',
#        'Discharged from the hospital - last 24H',
#        'Number of deaths - last 24H', 'Number inward as at today-10 am',
#        'Date', 'Total Number Confirmed', 'Total Number Recovered',
#        'Total Number of Deaths'],
#       dtype='object')

# %%
sns.relplot(x='Total Number Confirmed', y = 'Total Number Recovered', kind = 'line', data=data)
# Out:
# C:\Users\MSI\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
data.columns
# Out:
# Index(['Number inward as at yesterday-10 am', 'COVID 19 Positive - last 24H',
#        'Discharged from the hospital - last 24H',
#        'Number of deaths - last 24H', 'Number inward as at today-10 am',
#        'Date', 'Total Number Confirmed', 'Total Number Recovered',
#        'Total Number of Deaths'],
#       dtype='object')

# %%
sns.catplot(x='Total Number Recovered', y='Total Number Confirmed',data = data)
# Out:
# C:\Users\MSI\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='Total Number Confirmed', y = 'Number inward as at today-10 am', kind = 'line', data=data)
# Out:
# C:\Users\MSI\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
